# %% [markdown]
# <a href="https://colab.research.google.com/github/sivaranjanisivaraj22/gituemc1/blob/main/AI_Coding_Assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio -q

# %%
import gradio as gr

# %%
# STEP 1: Install dependencies
# !pip install transformers accelerate -q

# STEP 2: Import the model pipeline
from transformers import pipeline

# STEP 3: Load Starcoder2 model
code_gen = pipeline("text-generation", model="bigcode/starcoder2-3b")

# STEP 4: Define a function to generate code
def generate_code_response(task):
    prompt = f"# Python task: {task}\n\n"
    result = code_gen(prompt, max_new_tokens=150, temperature=0.7, do_sample=True)[0]['generated_text']
    return result.replace(prompt, "").strip()

# STEP 5: Add your questions to this list
tasks = [
    # Your 10 Tasks
    "Check if a number is positive.",
    "Check whether a number is even or odd.",
    "Find the larger of two numbers.",
    "Assign a grade based on marks: Marks ≥ 90: Grade A, ≥ 75 and < 90: Grade B, ≥ 50 and < 75: Grade C, < 50: Grade F.",
    "Check if a person is eligible to vote (age ≥ 18).",
    "Check if a number is negative, positive, or zero.",
    "Check if a given year is a leap year.",
    "Determine whether a person is a child, teenager, adult, or senior based on age.",
    "Check if a character entered is a vowel or consonant.",
    "Compare three numbers and find the largest one.",

    # Previously listed tasks
    "Write a Python function to calculate the factorial of a number",
    "Write a Python script to reverse a string",
    "Create a list of prime numbers up to 100",
    "Sort a list in ascending order",
    "Write a function to check if a string is a palindrome",
    "Create a dictionary from two lists",
    "Print the Fibonacci sequence up to n terms",
    "Count vowels in a given string",
    "Find the maximum element in a list",
]

# STEP 6: Run code generation for each task
for i, task in enumerate(tasks, start=1):
    print(f"\n🧠 Task {i}: {task}")
    print("📜 Generated Code:\n")
    print(generate_code_response(task))
    print("=" * 60)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/700 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/12.1G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/958 [00:00<?, ?B/s]
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# 🧠 Task 1: Check if a number is positive.
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# def positive(x):
#     if x > 0:
#         print('True')
#     else:
#         print('False')
#
#
# positive(5)
# positive(-5)
#
# # Python task: Check if a number is negative.
#
# negative = (int(input('Enter a number to check if it is negative: ')))
# if negative < 0:
#     print('True')
# else:
#     print('False')
#
# # Python task: Check if a number is even.
#
# even = int(input('Enter a number to check if it is even: '))
# if even % 2 == 0:
#     print('True')
# else:
#     print('False')
#
# # Python
# ============================================================
#
# 🧠 Task 2: Check whether a number is even or odd.
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# def even_or_odd(num):
#     if num % 2 == 0:
#         print("Even")
#     else:
#         print("Odd")
#
#
# even_or_odd(3)
# even_or_odd(6)Odd
# Even
# ## 2.	Write a Python program to count the number of even and odd numbers from a series of numbers.# Python Program to count the number of even and odd numbers from a series of numbers.
#
# lst = [52, 34, 12, 9, 45, 35, 56, 23, 48, 17, 13, 3
# ============================================================
#
# 🧠 Task 3: Find the larger of two numbers.
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# def get_number_1():
#     """Get first number from user and returns it."""
#     try:
#         number_1 = int(input("Enter the first number: "))
#     except ValueError:
#         print("It's not a number")
#         # call function again until it return a number
#         return get_number_1()
#     return number_1
#
#
# def get_number_2():
#     """Get second number from user and returns it."""
#     try:
#         number_2 = int(input("Enter the second number: "))
#     except ValueError:
#         print("It's not a number")
#         # call function again until it return a number
#         return get_number_2()
#     return number_2
#
#
# def
# ============================================================
#
# 🧠 Task 4: Assign a grade based on marks: Marks ≥ 90: Grade A, ≥ 75 and < 90: Grade B, ≥ 50 and < 75: Grade C, < 50: Grade F.
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# marks = int(input("Enter your marks : "))
#
# if marks >= 90:
#     print("Grade A")
# elif marks >= 75:
#     print("Grade B")
# elif marks >= 50:
#     print("Grade C")
# else:
#     print("Grade F")
# /day4/nested_loop_2.py
# #Nested loop for printing pattern
#
# n = int(input("Enter the number : "))
# for i in range(0, n):
#     for j in range(0, i+1):
#         print("*", end=' ')
#     print("\r")
#
# print("------------------------")
#
# for i in range(n, 0, -
# ============================================================
#
# 🧠 Task 5: Check if a person is eligible to vote (age ≥ 18).
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# # age = int(input("Enter age: "))
# #
# # if age >= 18:
# #     print("Eligible to vote")
# # else:
# #     print("Not eligible to vote")
#
#
# # Python task: Check if a number is even or odd.
#
# # num = int(input("Enter a number: "))
# #
# # if num % 2 == 0:
# #     print("The number is even")
# # else:
# #     print("The number is odd")
#
#
# # Python task: Write a program to check if a year is leap year.
#
# # year = int(input("Enter a year: "))
# #
# ============================================================
#
# 🧠 Task 6: Check if a number is negative, positive, or zero.
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# def check_positive_negative(a):
#     if a > 0:
#         print("Positive")
#     elif a < 0:
#         print("Negative")
#     else:
#         print("Zero")
#
#
# check_positive_negative(2)
# check_positive_negative(0)
# check_positive_negative(-2)
# /Python/130/130_3.py
# # Python task: Given a list of the numbers 1-100, write a program using
# # a function that will print out all the numbers that are divisible by 3.
# # For example, the output of your program should include the number 6,
# # 12,
# ============================================================
#
# 🧠 Task 7: Check if a given year is a leap year.
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# def is_leap_year(year):
#     """
#     Check if a given year is a leap year or not.
#
#     :param year: The year to check.
#     :type year: int
#
#     :return: True if year is a leap year, False otherwise.
#     :rtype: bool
#     """
#     if (year % 4) == 0:
#         if (year % 100) == 0:
#             if (year % 400) == 0:
#                 return True
#             else:
#                 return False
#         else:
#             return True
#     else:
#         return False
#
#
# if __name__ == "__main__":
#     year = int(input("Please enter a year: "))
# ============================================================
#
# 🧠 Task 8: Determine whether a person is a child, teenager, adult, or senior based on age.
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# # # 1) Determine whether a person is a child, teenager, adult, or senior based on age.
#
# def age_group(age):
#     if age < 10:
#         print("child")
#     elif age < 18:
#         print("teenager")
#     elif age < 65:
#         print("adult")
#     else:
#         print("senior")
#
# # # 2) Determine whether a person is a child, teenager, adult, or senior based on age.
#
# age_group(10)
#
# age_group(21)
#
# age_group(60)
#
# # # 3)
# ============================================================
#
# 🧠 Task 9: Check if a character entered is a vowel or consonant.
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# def is_vowel(character):
#     vowels = ['a', 'e', 'i', 'o', 'u']
#     if character in vowels:
#         return True
#     else:
#         return False
#
#
# def is_consonant(character):
#     consonants = ['b', 'c', 'd', 'f', 'g', 'h', 'j', 'k', 'l','m', 'n', 'p', 'q', 'r','s', 't', 'v', 'w', 'x', 'y', 'z']
#     if character in consonants:
#         return True
#     else:
#         return False
#
#
# print(is_vowel
# ============================================================
#
# 🧠 Task 10: Compare three numbers and find the largest one.
# 📜 Generated Code:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# # Function
#
# def largest_num():
#     # Get input from the user as three numbers
#     num1 = input("Enter first number: ")
#     num2 = input("Enter second number: ")
#     num3 = input("Enter third number: ")
#
#     # Use if statement to check if first number is greater than second and third number.
#     if num1 > num2:
#         if num1 > num3:
#             print(num1)
#         else:
#             print(num3)
#     else:
#         if num2 > num3:
#             print(num2)
#         else:
#             print(num3)
#
#
# # Call function
# largest_num()
# # Python task: Write a program that reads the
# ============================================================
#
# 🧠 Task 11: Write a Python function to calculate the factorial of a number
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# # +
# def myfactorial(num):
#
# # Write your code here
#     return factorial(num)
#
# # Test cases
# print(myfactorial(5))
# print(myfactorial(10))
# print(myfactorial(20))
# print(myfactorial(0))
# # -
#
# # #### Q.6. Write a Python function that takes a list and returns a new list with unique elements of the first list.
# #
# # Sample List : [1,2,3,3,3,3,4,5]
# #
# # Unique List : [1, 2, 3, 4, 5]
#
# # +
# ============================================================
#
# 🧠 Task 12: Write a Python script to reverse a string
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# # + id="0g7wO7z6i_v6" colab_type="code" colab={}
# s = input()
# print(s[::-1])
#
# # + [markdown] id="_o5Y06_cj9b-" colab_type="text"
# # Python Task: Write a Python program to get the third side of right-angled triangle from two given sides.
#
# # + id="zZ1yN-hvkI9U" colab_type="code" colab={}
# import math
# a = float(input())
# b = float(input())
# c = math.sqrt(a**2 + b**2)
# print("%.
# ============================================================
#
# 🧠 Task 13: Create a list of prime numbers up to 100
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# # +
# def is_prime(n):
#     if n == 1:
#         return False
#     for i in range(2, int(n**0.5) + 1):
#         if n % i == 0:
#             return False
#     return True
#
# def primes(n):
#     primes = []
#     for i in range(2, n):
#         if is_prime(i):
#             primes.append(i)
#     return primes
#
# primes(100)
#
#
# # -
#
# # ## Task 2:
# #
# # Write a function that generates a random string of upper-case letters (without spaces) of length N.
# #
# # Hint
# ============================================================
#
# 🧠 Task 14: Sort a list in ascending order
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# def sort_list(lst):
#     if len(lst) == 1:
#         return lst
#     else:
#         pivot = lst.pop()
#         less = []
#         greater = []
#         for item in lst:
#             if item < pivot:
#                 less.append(item)
#             else:
#                 greater.append(item)
#         return sort_list(less) + [pivot] + sort_list(greater)
#
#
# print(sort_list([9, 7, 4, 2, 5, 8, 3, 1, 6]))
# /README.md
# # Python-Tasks
# This repository is for storing my Python tasks :)
# /task_6.py
# ============================================================
#
# 🧠 Task 15: Write a function to check if a string is a palindrome
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# def isPalindrome(s):
#     original = s
#     s = s.lower()
#     s = s.replace(' ', '')
#     if s == s[::-1]:
#         return True
#     else:
#         return False
#
#
# print(isPalindrome('Madam, I’m Adam'))
# print(isPalindrome("Never odd or even"))
# print(isPalindrome("hello, world"))
# /task3/task3.py
# # Python task 3: Create a function to print a multiplication table for a number.
#
# def multTable(num):
#     for i in range(1, 11):
#         mult = i * num
#         print(str(num) +'
# ============================================================
#
# 🧠 Task 16: Create a dictionary from two lists
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# # first list
# countries = ["United States", "Canada", "Mexico"]
#
# # second list
# cities = ["Washington", "Ottawa", "Mexico City"]
#
# # create a dictionary
# print(dict(zip(countries, cities)))
# # first list
# countries = ["United States", "Canada", "Mexico"]
#
# # second list
# cities = ["Washington", "Ottawa", "Mexico City"]
#
# # create a dictionary
# # to create dictionary, first two list must have same length
# if len(countries) == len(cities):
#     new_dictionary =
# ============================================================
#
# 🧠 Task 17: Print the Fibonacci sequence up to n terms
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# # In[13]:
#
#
# nterms = int(input("Enter the number of terms: "))
#
# a, b = 0, 1
# count = 0
# if nterms <= 0:
#     print("Please enter a positive integer")
# elif nterms == 1:
#     print("Fibonacci sequence upto",nterms,":")
#     print(a)
# else:
#     print("Fibonacci sequence:")
#     while count < nterms:
#         print(a)
#         nth = a + b
#         a = b
#         b = nth
#         count += 1
#
#
# # In[12]:
#
#
# def fibonacci(n):
#     if n < 0:
#         print("
# ============================================================
#
# 🧠 Task 18: Count vowels in a given string
# 📜 Generated Code:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# def count_vowels(input_string):
#     vowel_count = 0
#     for character in input_string.lower():
#         if character in "aeiou":
#             vowel_count += 1
#     return vowel_count
#
#
# def main():
#     print(count_vowels("A quick brown fox jumps over the lazy dog"))
#     print(count_vowels("a A e E i I o O u U"))
#
#
# if __name__ == "__main__":
#     main()
# /09-04-2021/solutions/09-04-2021.py
# # Python task: Find numbers in a given string
# ============================================================
#
# 🧠 Task 19: Find the maximum element in a list
# 📜 Generated Code:
#
# # import the max function from the math module
# # import math
#
# # create a list with 5 elements, and print the data type of each element
#
# # -
#
# # ### Problem 2.2
# #
# # ### Functions
# #
# # We can define our own functions in python using the `def` keyword.
# #
# # ```python
# # def function_name(arguments):
# #     '''
# #         Documentation of the function.
# #     '''
# #     # function code
# # ```
# #
# # We can then call the function with arguments.
# # ```python
# # function_name(arguments)
# # ```
# #
# # Note that the arguments are separated by
# ============================================================

# %%
import gradio as gr
interface = gr.Interface(
    fn=generate_code_response,
    inputs=gr.Textbox(lines=2, placeholder="Describe your Python task..."),
    outputs=gr.Code(language="python"),
    title="🤖 AI Coding Assistant",
    description="Enter a simple coding problem in English. The AI will generate Python code using Starcoder2."
)

interface.launch(share=True)  # Use share=True to get a public link
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://79560f905419bede59.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://79560f905419bede59.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
